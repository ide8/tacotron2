# %%
import os
import librosa
import numpy as np
from tqdm import tqdm
from scipy.io import wavfile

mels_in_path = "/Users/ide8/Projects/kami/torch/DL/PyTorch/SpeechSynthesis/mels_trimed"

sr = 22050
maxv = np.iinfo(np.int16).max

mels = os.listdir(mels_in_path)

import matplotlib.pyplot as plt
# %matplotlib inline
import torch
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-91-e30a13786a60> in <module>
#      10 maxv = np.iinfo(np.int16).max
#      11
# ---> 12 mels = os.listdir(mels_in_path)
#      13
#      14 import matplotlib.pyplot as plt
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ide8/Projects/kami/torch/DL/PyTorch/SpeechSynthesis/mels'

# %%
for i, mel in tqdm(enumerate(mels)):
    data = torch.load(os.path.join(mels_in_path, mel))

    print(mel)
    plt.imshow(data.numpy())
    if i == 1:
        break
    #wavfile.write(os.path.join(wavs_out_path, wav), sr, (data*maxv).astype(np.int16))
# Out:
# 0it [00:00, ?it/s]
# audio-13977.100-13985.200.pt
# audio-109.100-115.700.pt

# %%
import os
import librosa
import numpy as np
from tqdm import tqdm
from scipy.io import wavfile
import IPython.display as ipd

sr = 22050
top_db = 120
maxv = np.iinfo(np.int32).max

# %%
wav_in_path = 'raw.wav'
out_path = 'p.wav'

# %%
data, _ = librosa.load(wav_in_path, sr=sr)

# %%
data
# Out:
# array([ 0.17294759,  0.23522782,  0.18577705, ...,  0.00575637,
#         0.00218457, -0.00037459], dtype=float32)

# %%
wavfile.write(out_path, sr, data)

# %%
ipd.Audio(out_path)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
